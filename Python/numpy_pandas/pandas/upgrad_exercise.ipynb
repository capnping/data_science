# %%
import pandas as pd

# %%
movies = pd.read_csv('Movies.csv')

# %%
movies.shape
# Out:
# (3853, 28)

# %%
len(movies.columns[movies.isnull().any()].tolist())
# Out:
# 12

# %%
len(movies.columns)
# Out:
# 28

# %%
movies.drop('color', axis=1)
# Out:
#           director_name  num_critic_for_reviews  duration  \
# 0         James Cameron                   723.0     178.0
# 1        Gore Verbinski                   302.0     169.0
# 2            Sam Mendes                   602.0     148.0
# 3     Christopher Nolan                   813.0     164.0
# 4        Andrew Stanton                   462.0     132.0
# ...                 ...                     ...       ...
# 3848      Shane Carruth                   143.0      77.0
# 3849   Neill Dela Llana                    35.0      80.0
# 3850   Robert Rodriguez                    56.0      81.0
# 3851       Edward Burns                    14.0      95.0
# 3852           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes        actor_2_name  \
# 0                         0.0                   855.0    Joel David Moore
# 1                       563.0                  1000.0       Orlando Bloom
# ...

# %%
movies = movies.drop(['color', 'director_facebook_likes',
'actor_1_facebook_likes',
'actor_2_facebook_likes',
'actor_3_facebook_likes',
'actor_2_name',
'cast_total_facebook_likes',
'actor_3_name',
'duration',
'facenumber_in_poster',
'content_rating',
'country',
'movie_imdb_link',
'aspect_ratio',
'plot_keywords'], axis=1)

# %%
movies.isnull().sum()
# Out:
# director_name             0
# num_critic_for_reviews    1
# gross                     0
# genres                    0
# actor_1_name              0
# movie_title               0
# num_voted_users           0
# num_user_for_reviews      0
# language                  3
# budget                    0
# title_year                0
# imdb_score                0
# movie_facebook_likes      0
# dtype: int64

# %%
movies.index
# Out:
# RangeIndex(start=0, stop=3853, step=1)

# %%
movies[movies['language'] == 'English']
# Out:
#           director_name  num_critic_for_reviews        gross  \
# 0         James Cameron                   723.0  760505847.0
# 1        Gore Verbinski                   302.0  309404152.0
# 2            Sam Mendes                   602.0  200074175.0
# 3     Christopher Nolan                   813.0  448130642.0
# 4        Andrew Stanton                   462.0   73058679.0
# ...                 ...                     ...          ...
# 3844        John Waters                    73.0     180483.0
# 3848      Shane Carruth                   143.0     424760.0
# 3849   Neill Dela Llana                    35.0      70071.0
# 3851       Edward Burns                    14.0       4584.0
# 3852           Jon Gunn                    43.0      85222.0
#
#                                genres     actor_1_name  \
# 0     Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1            Action|Adventure|Fantasy      Johnny Depp
# 2           Action|Adventure|Thriller  Christoph Waltz
# ...

# %%
movies.loc[pd.isnull(movies['language']), ['language']] = 'English'

# %%
movies['net_profit'] = movies['gross'] - movies['budget']

# %%
movies.sort_values('net_profit', ascending=False).head()
# Out:
#          director_name  num_critic_for_reviews        gross  \
# 0        James Cameron                   723.0  760505847.0
# 28     Colin Trevorrow                   644.0  652177271.0
# 25       James Cameron                   315.0  658672302.0
# 2704      George Lucas                   282.0  460935665.0
# 2748  Steven Spielberg                   215.0  434949459.0
#
#                                 genres         actor_1_name  \
# 0      Action|Adventure|Fantasy|Sci-Fi          CCH Pounder
# 28    Action|Adventure|Sci-Fi|Thriller  Bryce Dallas Howard
# 25                       Drama|Romance    Leonardo DiCaprio
# 2704   Action|Adventure|Fantasy|Sci-Fi        Harrison Ford
# 2748                     Family|Sci-Fi         Henry Thomas
#
#                               movie_title  num_voted_users  \
# 0                                 Avatar            886204
# 28                        Jurassic World            418214
# ...

# %%
movies[(movies['imdb_score'] >=7.5) & (movies['imdb_score'] <=8.5)].shape
# Out:
# (614, 14)

# %%
movies[(movies['imdb_score'] >=9) & (movies['imdb_score'] <=9.5)].shape
# Out:
# (4, 14)
